# %%
import json as f

# %%
with open(r'C:\Users\Ashu\Desktop\OpenGovDataHack\Working\Education_and_Skilling_v1\Dataset\Classification_of_secondary_schools_by_management_in_Haryana.json','r') as f:
    RawData = f.read()

# %%
RawData
# Out:
# '{"fields":[{"id":"a","label":"Year\\/District","type":"string"},{"id":"b","label":"Government","type":"string"},{"id":"c","label":"Non-Govt.","type":"string"},{"id":"d","label":"For Boys","type":"string"},{"id":"e","label":"For Girls","type":"string"},{"id":"f","label":"Total","type":"string"}],"data":[["1966-67","440","157","488","109","597"],["1970-71","797","178","811","164","975"],["1975-76","907","222","931","198","1129"],["1980-81","1226","247","1228","245","1473"],["1985-86","1657","289","1643","303","1946"],["1990-91","1944","412","2001","355","2356"],["1995-96","2345","653","2547","451","2998"],["2000-01","2620","1518","3631","507","4138"],["2005-06","2827","2490","4781","536","5317"],["2010-11","3167","3816","6425","558","6983"],["2011-12","3214","3890","6470","590","7060"],["2012-13 (P)","3159","4179","6819","519","7338"],["Ambala","155","143","288","10","298"],["Panchkula","58","61","116","3","119"],["Yamunanagar","111","215","321","5","326"],["Kurukshetra","112","168","
# ...

# %%
DataObj = json.loads(RawData)

# %%
DataObj
# Out:
# {'fields': [{'id': 'a', 'label': 'Year/District', 'type': 'string'},
#   {'id': 'b', 'label': 'Government', 'type': 'string'},
#   {'id': 'c', 'label': 'Non-Govt.', 'type': 'string'},
#   {'id': 'd', 'label': 'For Boys', 'type': 'string'},
#   {'id': 'e', 'label': 'For Girls', 'type': 'string'},
#   {'id': 'f', 'label': 'Total', 'type': 'string'}],
#  'data': [['1966-67', '440', '157', '488', '109', '597'],
#   ['1970-71', '797', '178', '811', '164', '975'],
#   ['1975-76', '907', '222', '931', '198', '1129'],
#   ['1980-81', '1226', '247', '1228', '245', '1473'],
#   ['1985-86', '1657', '289', '1643', '303', '1946'],
#   ['1990-91', '1944', '412', '2001', '355', '2356'],
#   ['1995-96', '2345', '653', '2547', '451', '2998'],
#   ['2000-01', '2620', '1518', '3631', '507', '4138'],
#   ['2005-06', '2827', '2490', '4781', '536', '5317'],
#   ['2010-11', '3167', '3816', '6425', '558', '6983'],
#   ['2011-12', '3214', '3890', '6470', '590', '7060'],
# ...

# %%
DataObj.keys()
# Out:
# dict_keys(['fields', 'data'])

# %%
len_Col = len(DataObj['fields'])
Cols = [list(DataObj['fields'][i].values())[1] for i in range(len_Col)]

# %%
Cols
# Out:
# ['Year/District', 'Government', 'Non-Govt.', 'For Boys', 'For Girls', 'Total']

# %%
import pandas as p
Data = p.DataFrame(DataObj['data'],columns = Cols)
Data.head()
# Out:
#   Year/District Government Non-Govt. For Boys For Girls Total
# 0       1966-67        440       157      488       109   597
# 1       1970-71        797       178      811       164   975
# 2       1975-76        907       222      931       198  1129
# 3       1980-81       1226       247     1228       245  1473
# 4       1985-86       1657       289     1643       303  1946

# %%
type(Data)
# Out:
# pandas.core.frame.DataFrame

# %%
list(dir(Data))
# Out:
# ['Government',
#  'T',
#  'Total',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
print(Data.shape)
print(Data.size)
print(len(Data))
# Out:
# (32, 6)
# 192
# 32

# %%
type(Data['Year/District'])
# Out:
# pandas.core.series.Series

# %%
DatabyYearMO = Data[:11]

DatabyDistrict = Data[12:]

# %%
# Out:
#   Year/District Government Non-Govt. For Boys For Girls Total
# 0       1966-67        440       157      488       109   597
# 1       1970-71        797       178      811       164   975
# 2       1975-76        907       222      931       198  1129
# 3       1980-81       1226       247     1228       245  1473
# 4       1985-86       1657       289     1643       303  1946
